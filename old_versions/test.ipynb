# %%
import sys
sys.path.append('C:\\Users\\bcurl\\Desktop\\Audit_Tool_2.0\\util\\trip_data.py')
sys.path.append('C:\\Users\\bcurl\\Desktop\\Audit_Tool_2.0\\util\\df_functions.py')

# %%
from auditclasses import *

# %%
file_path = "C:\\Users\\bcurl\\Desktop\\Audit_Tool_2.0\\util\\2023.03.23-2023.05.28 MR Export.csv"
export_df = pd.read_csv(file_path)
trip_df = WeeklyAudit(export_df)
# Out:
# C:\Users\bcurl\AppData\Local\Temp\ipykernel_17176\3119408374.py:2: DtypeWarning: Columns (11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   export_df = pd.read_csv(file_path)
# c:\Users\bcurl\Desktop\Audit_Tool_2.0\util\auditclasses.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   trips_in_range_df = trips_in_range_df.append(

# %%
trip_df.add_data()

# %%
ooa = trip_df.ooa_export()
ooa
# Out:
#        Client First Name Client Last Name Customer Number  Trip ID  \
# 2595            CRISTIAN          MELLADO        EO301R9V  4548293
# 2596            CRISTIAN          MELLADO        EO301R9V  4548305
# 2597            CRISTIAN          MELLADO        EO301R9V  4548301
# 2598            CRISTIAN          MELLADO        EO301R9V  4548298
# 2599            CRISTIAN          MELLADO        EO301R9V  4548300
# ...                  ...              ...             ...      ...
# 303485           RICHARD           REUTER        IW000N7R  4837217
# 303508           RICHARD           REUTER        IW000N7R  4837202
# 303574           WILLIAM            MOORE        VI101F1K  4785373
# 303897           RICHARD           REUTER        IW000N7R  4837218
# 303903           RICHARD           REUTER        IW000N7R  4837203
#
#          Trip Date Trip Status   Cancel Type            Verification  \
# 2595    03/23/2023        comp                       Ride Connection
# ...

# %%
trip_p = trip_df.trip_purpose_error()
trip_p
# Out:
#        Client First Name Client Last Name Customer Number  Trip ID  \
# 14312               EDDA           MICALE        KD501R5K  4727392
# 21978             ANDREA           KEARNS        CH13045A  4561640
# 25903               EDDA           MICALE        KD501R5K  4727413
# 81167               ANNA         TSVETKOV        GA300X3P  4624478
# 89818               EDDA           MICALE        KD501R5K  4727556
# 245199              ALVA            MYERS        HA701B8U  4778527
#
#          Trip Date Trip Status   Cancel Type   Verification  \
# 14312   03/26/2023      cancel        Denial           None
# 21978   03/28/2023      cancel        Denial  First Transit
# 25903   03/28/2023      cancel        Denial           None
# 81167   04/10/2023      cancel  Not Selected           None
# 89818   04/11/2023      cancel        Denial           None
# 245199  05/16/2023      cancel        Denial           None
#
#                 OSA or Negotiated Rate Distribution Date  ...  \
# ...

# %%
blank_provider = trip_df.blank_provider_iso()

# %%
blank_provider
# Out:
#        Client First Name Client Last Name Customer Number  Trip ID  \
# 81780              KAYLA          SAUCEDO        ER501S6T  4624546
# 82214              KAYLA          SAUCEDO        ER501S6T  4624544
# 141824           MALINDA           ATWOOD        UD500K9S  4677851
# 180231            ANDREW             HREN        CP200K6R  4817164
# 180232            ANDREW             HREN        CP200K6R  4817166
# 192213            ANDREW             HREN        CP200K6R  4817266
# 192214            ANDREW             HREN        CP200K6R  4817272
# 229509            ANGELA           STERBA        CH70185D  4773478
# 230316            ELIJAH         CHITWOOD        SF401N9K  4794323
# 238537            ANDREW             HREN        CP200K6R  4817335
# 247744         CHRISTINA            YOUNG        AI66977A  4792317
# 268859            ANDREW             HREN        CP200K6R  4817285
#
#          Trip Date Trip Status Cancel Type Verification  \
# ...
